# %%
from wand.image import Image as wi
from wand.display import display
from timeit import default_timer
import os

# %%
print(os.path.exists("001.jpg"))
# Out:
# True

# %%
img = wi(filename="001.jpg")

# %%
img.crop(bottom=int(img.height/2))
# Out:
# True

# %%
img
# Out:
# <wand.image.Image: f154c19 'JPEG' (1654x1170)>
